# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(1, "../")

# %% [markdown]
# # Determine all possible outputs

# %%
from utils import prepare_path, read_yaml

output_config = read_yaml(prepare_path("output_configuration.yaml"))

complete_set = set()
for set in output_config.keys():
    for output in output_config[set]:
        complete_set.add(output)

complete_set
# Out:
# {'payments', 'report', 'stratification'}
